# %%
# prompt: find version shap using python

import shap
print(shap.__version__)

import sys
print(sys.version)

import tensorflow as tf
print(tf.__version__)
# Out:
# 0.46.0
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]
# 2.17.0
